# %%
class Human:
    def __init__(self,name,age):
        self.name = name
        self.age = age

    def printinfo(self):
      print(self.name)
      print(self.age)

human_a = Human("太郎",30)
human_a.printinfo()
# Out:
# 太郎
# 30
